# %% [markdown]
# # Iris dataset

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
age =  np.arange(1,11,1)

# %%
weight = np.arange(5,55,5)

# %%
print(weight)
# Out:
# [ 5 10 15 20 25 30 35 40 45 50]

# %%
plt.figure(figsize=(8,6))
ax = sns.lineplot(x=age, y=weight)
plt.show()
